# %% [markdown]
# <a href="https://colab.research.google.com/github/Sebastiandelgado14/programacion1/blob/main/Tarea_2_Hailer_Delgado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hailer Sebastián Delgado Jerez - 2230128
# #Parte 1 Tarea 2

# %% [markdown]
# #Instrucción 1
# Adjunte un link de Github en el mismo archivo PDF los códigos y sus resultados desarrollados en los vídeos.
#
# Nota: aqui se dejarán los códigos tal cuál se indican en el video y se observará los resultados de ello, en la siguiente instrucción colocada posteriormente aparecen los códigos modificados con sus respectivos resultados.

# %% [markdown]
# #video de estructuras de datos en phyton

# %%
# Listas

lista = [29, True, 3.1415, "El número de Avogadro sí que mola"]

print(lista)
print(lista[-1])
print(lista[1:3])

lista[2] = "He cambiado este elemento"

lista[2] = [3, 2, 1]
print(lista)

print(len(lista))
# Out:
# [29, True, 3.1415, 'El número de Avogadro sí que mola']
# El número de Avogadro sí que mola
# [True, 3.1415]
# [29, True, [3, 2, 1], 'El número de Avogadro sí que mola']
# 4

# %%
lista_nueva = [1, 2, 3, 4, 5]

lista_nueva.append(3)

print(lista_nueva)

print(lista_nueva.count(3))

print(lista_nueva.index(4))

lista_nueva.remove(3)

print(lista_nueva)
# Out:
# [1, 2, 3, 4, 5, 3]
# 2
# 3
# [1, 2, 4, 5, 3]

# %%
# Tuplas

tupla = ("¿La tierra es plana?", True, False)
print(tupla)

print(tupla[0])
print(tupla[1])
print(tupla[2])

print(tupla.count(True))
print(tupla.index(False))

print((1))
print((1,))
# Out:
# ('¿La tierra es plana?', True, False)
# ¿La tierra es plana?
# True
# False
# 1
# 2
# 1
# (1,)

# %%
# Conjunto

print(set())

print(set([5, 2, 5, 1, 1.5]))
print(set((5, 2, 5, 1, 1.5)))
print(set("52511.5"))

conjunto = set([2, 3, 3, 4])
conjunto_2 = set([5, 3, 5, 6])
conjunto_3 = set([4, 2])

print(conjunto)
print(conjunto_2)
print(conjunto_3)

conjunto.add(1)
print(conjunto)

conjunto.remove(1)
print(conjunto)

print(conjunto.intersection(conjunto_2))
print(conjunto_2.issubset(conjunto))
print(conjunto_3.issubset(conjunto))
# Out:
# set()
# {1, 2, 5, 1.5}
# {1, 2, 5, 1.5}
# {'5', '1', '2', '.'}
# {2, 3, 4}
# {3, 5, 6}
# {2, 4}
# {1, 2, 3, 4}
# {2, 3, 4}
# {3}
# False
# True

# %%
# Diccionario

diccionario = {1: "Uno", 2: "Dos"}
diccionario[3] = "Tres"
print(diccionario)

dict_lista_tuplas = dict([(1, "Uno"), (2, "Dos"), (3, "Tres")])
print(dict_lista_tuplas)

dict_lista_string = dict(Uno = 1, Dos = 2, Tres = 3)
print(dict_lista_string)

dict_tipos = {1: "integer",
              2.2: "float",
              "texto": "string",
              (1, 2): "tupla"}

print(dict_tipos)

dict_repeticion = {1: "Primero", 1: "Último"}
print(dict_repeticion)

print(diccionario,
      diccionario.keys(),
      diccionario.values(),
      diccionario.items())

claves = diccionario.values()
print(claves)
diccionario[1] = "One"
print(claves)
diccionario.pop(2)
print(diccionario)
# Out:
# {1: 'Uno', 2: 'Dos', 3: 'Tres'}
# {1: 'Uno', 2: 'Dos', 3: 'Tres'}
# {'Uno': 1, 'Dos': 2, 'Tres': 3}
# {1: 'integer', 2.2: 'float', 'texto': 'string', (1, 2): 'tupla'}
# {1: 'Último'}
# {1: 'Uno', 2: 'Dos', 3: 'Tres'} dict_keys([1, 2, 3]) dict_values(['Uno', 'Dos', 'Tres']) dict_items([(1, 'Uno'), (2, 'Dos'), (3, 'Tres')])
# dict_values(['Uno', 'Dos', 'Tres'])
# dict_values(['One', 'Dos', 'Tres'])
# {1: 'One', 3: 'Tres'}

# %% [markdown]
# ### Ejercicio Listas:

# %%
personajes = ["Kakyoin", "Joseph", "Jotaro"]
personajes.remove("Kakyoin")
personajes.append("Polnareff")
resultado = personajes[1:2]
print(resultado)
# Out:
# ['Jotaro']

# %% [markdown]
# ###Ejercicio Tuplas:

# %%
respuesta = ("Yes","Yes","Yes")
resultado = (respuesta.count("Yes"), respuesta.index("Yes"))
print(resultado)
# Out:
# (3, 0)

# %% [markdown]
# ###Ejercicio Conjuntos:

# %%
temporada_2 = set(["Joseph", "Caesar"])
temporada_3 = set(["Jotaro", "Joseph", "Avdol", "Kakyoin", "Polnareff"])
resultado = temporada_2 & temporada_3
print(resultado)
# Out:
# {'Joseph'}

# %% [markdown]
# ###Ejercicio Diccionarios:

# %%
protas = {1: "Jonnathan", 2: "Joseph", 3: "Jotaro"}
jojos = {"Jonnathan": "Phantom Blood",
         "Joseph": "Battle Tendency",
         "Jotaro": "Stardust Crusaders"}
resultado = jojos[protas[3]]
print(resultado)
# Out:
# Stardust Crusaders

# %% [markdown]
# #Video sobre estructuras de Control de Flujo

# %%
# Ejemplo de conversión de distintos tipos a False

print(0, "->", bool(0))
print(0.0, "->", bool(0.0))
print("", "->", bool(""))
print(list(), "->", bool(list()))
print(tuple(), "->", bool(tuple()))
print(set(), "->", bool(set()))
print(dict(), "->", bool(dict()))
print(None, "->", bool(None))
# Out:
# 0 -> False
# 0.0 -> False
#  -> False
# [] -> False
# () -> False
# set() -> False
# {} -> False
# None -> False

# %%
# Ejemplo de conversión de distintos tipos a True

print(9000, "->", bool(9000))
print(3.1415, "->", bool(3.1415))
print("Cadena", "->", bool("Cadena"))
print(list((1, 2)), "->", bool(list((1, 2))))
print(tuple((1, 2)), "->", bool(tuple((1, 2))))
print(set((1, 2)), "->", bool(set((1, 2))))
print(dict([(1,2)]), "->", bool(dict([(1,1)])))
# Out:
# 9000 -> True
# 3.1415 -> True
# Cadena -> True
# [1, 2] -> True
# (1, 2) -> True
# {1, 2} -> True
# {1: 2} -> True

# %%
# Ejemplo if-else

nota = float(input("Introduzca su nota: "))
if nota < 5:
  print("Estás suspenso, F")
else:
  print("Estás aprobado, ¡enhorabuena!")
# Out:
# Introduzca su nota: 5
# Estás aprobado, ¡enhorabuena!

# %%
#Ejemplo if-elif-else

nota = float(input("Introduzca su nota: "))
if 0 <= nota and nota < 5:
  print("Estás suspenso, F")
elif 5 <= nota and nota < 7:
  print("Aprobado")
elif 7 <= nota and nota < 9:
  print("Notable")
elif 9 <= nota and nota <= 10:
  print("Sobresaliente")
else:
  print("Nota fuera de rango")
# Out:
# Introduzca su nota: 2
# Estás suspenso, F

# %%
# Ejemplo while

contador = 3
while contador != 0:
  contador = contador - 1
  print("El contenido de contador es", contador)
# Out:
# El contenido de contador es 2
# El contenido de contador es 1
# El contenido de contador es 0

# %%
# Ejemplo básico del for

for iterador in [1, 2, 3]:
  print(iterador)
# Out:
# 1
# 2
# 3

# %%
# for sobre estructuras de datos

lista = list((2, 1, 0))
tupla = tuple((2, 1, 0))
conjunto = set((2, 1, 0))
diccionario = dict(((2,"Dos"), (1, "Uno"), (0, "Cero")))

for iterador in lista:
  print(iterador)
# Out:
# 2
# 1
# 0

# %%
# Acceso por índices a una lista con un for

lista = ["Vamos", "a", "acceder", "a", "esta", "lista", "por", "índices"]

for indice in range(len(lista)):
  print("Indice:", indice,"Elemento:", lista[indice])
# Out:
# Indice: 0 Elemento: Vamos
# Indice: 1 Elemento: a
# Indice: 2 Elemento: acceder
# Indice: 3 Elemento: a
# Indice: 4 Elemento: esta
# Indice: 5 Elemento: lista
# Indice: 6 Elemento: por
# Indice: 7 Elemento: índices

# %%
# for para visualizar el efecto de las sentencias break y continue

for numero in range(5):
  print(numero)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Visualización del efecto de la sentencia break

for numero in range(5):
  if numero == 3:
    break
  print(numero)
# Out:
# 0
# 1
# 2

# %%
# Visualización del efecto de la sentencia continue

for numero in range(5):
  if numero == 3:
    continue
  print(numero)
# Out:
# 0
# 1
# 2
# 4

# %%
# Uso del else en un while

intentos = 3
while intentos > 0:
  if input(">>> Escriba la contraseña:") == "BitBoss":
    print("¡Correcta!")
    break
  intentos = intentos - 1
  print("Contraseña incorrecta")
else:
  print("Se te acabaron los intentos :(")
# Out:
# >>> Escriba la contraseña:BitBo
# Contraseña incorrecta
# >>> Escriba la contraseña:BitBoss
# ¡Correcta!

# %% [markdown]
# #Instrucción 2
# A partir del Google colab referenciado en los vídeos, modifique ligeramente los códigos y muestre
# los resultados en el link de Github relacionado previamente.
#
# Nota: Aquí si se modifican los códigos dados en los videos

# %% [markdown]
# #video de estructuras de datos en python

# %%
#listas
datos_cientificos = [
    "Número de Avogadro",
    6.022e23,
    True,
    "Constante fundamental en química"
]

print(datos_cientificos)
print(datos_cientificos[-1])
print(datos_cientificos[1:3])

# Modificación de elementos
datos_cientificos[2] = False
datos_cientificos[1] = [6.022, "x10^23"]

print(datos_cientificos)

print(len(datos_cientificos))
# Out:
# ['Número de Avogadro', 6.022e+23, True, 'Constante fundamental en química']
# Constante fundamental en química
# [6.022e+23, True]
# ['Número de Avogadro', [6.022, 'x10^23'], False, 'Constante fundamental en química']
# 4

# %%
#listas
lista_nueva = [10, 20, 30, 40, 50]

lista_nueva.append(30)

print(lista_nueva)

print(lista_nueva.count(30))

print(lista_nueva.index(40))

print("Primer elemento:", lista_nueva[0])
print("Último elemento:", lista_nueva[-1])

print("Sublista:", lista_nueva[1:4])

lista_nueva.remove(30)

print(lista_nueva)
print("Nuevo índice de 30:", lista_nueva.index(30))
# Out:
# [10, 20, 30, 40, 50, 30]
# 2
# 3
# Primer elemento: 10
# Último elemento: 30
# Sublista: [20, 30, 40]
# [10, 20, 40, 50, 30]
# Nuevo índice de 30: 4

# %%
#sobre tuplas
tupla = ("¿El agua hierve a 100°C?", True, False)

print(tupla)
print(tupla[0])
print(tupla[1])
print(tupla[2])

# Operaciones con la tupla, explicadas en el video
print(tupla.count(True))
print(tupla.index(False))

# Ejemplo de tuplas de un solo elemento, note la diferencia explicada en el video.
print((2))
print((2,))
# Out:
# ('¿El agua hierve a 100°C?', True, False)
# ¿El agua hierve a 100°C?
# True
# False
# 1
# 2
# 2
# (2,)

# %%
#conjuntos
print(set())

print(set([101, 102, 101, 103, 104.5]))
print(set((101, 102, 101, 103, 104.5)))
print(set("101122.5"))

curso_A = set([1, 2, 2, 3])
curso_B = set([3, 4, 4, 5])
curso_C = set([2, 3])

print(curso_A)
print(curso_B)
print(curso_C)

curso_A.add(6)
print(curso_A)
curso_A.remove(6)
print(curso_A)

print("Intersección A y B:", curso_A.intersection(curso_B))
print("¿B es subconjunto de A?:", curso_B.issubset(curso_A))
print("¿C es subconjunto de A?:", curso_C.issubset(curso_A))
# Out:
# set()
# {104.5, 101, 102, 103}
# {104.5, 101, 102, 103}
# {'1', '.', '0', '5', '2'}
# {1, 2, 3}
# {3, 4, 5}
# {2, 3}
# {1, 2, 3, 6}
# {1, 2, 3}
# Intersección A y B: {3}
# ¿B es subconjunto de A?: False
# ¿C es subconjunto de A?: True

# %%
#Diccionario
diccionario = {1: "Matemáticas", 2: "Física"}
diccionario[3] = "Química"
print(diccionario)

dict_lista_tuplas = dict([(1, "Matemáticas"), (2, "Física"), (3, "Química")])
print(dict_lista_tuplas)

dict_lista_string = dict(Matematicas = 90, Fisica = 85, Quimica = 88)
print(dict_lista_string)

dict_tipos = {
    1: "Código",
    2.5: "Promedio",
    "nombre": "Asignatura",
    (1, 2): "Par ordenado"
}

print(dict_tipos)


dict_repeticion = {1: "Inicial", 1: "Final"}
print(dict_repeticion)


print(diccionario,
      diccionario.keys(),
      diccionario.values(),
      diccionario.items())


valores = diccionario.values()
print(valores)


diccionario[1] = "Álgebra"
print(valores)

diccionario.pop(2)
print(diccionario)
# Out:
# {1: 'Matemáticas', 2: 'Física', 3: 'Química'}
# {1: 'Matemáticas', 2: 'Física', 3: 'Química'}
# {'Matematicas': 90, 'Fisica': 85, 'Quimica': 88}
# {1: 'Código', 2.5: 'Promedio', 'nombre': 'Asignatura', (1, 2): 'Par ordenado'}
# {1: 'Final'}
# {1: 'Matemáticas', 2: 'Física', 3: 'Química'} dict_keys([1, 2, 3]) dict_values(['Matemáticas', 'Física', 'Química']) dict_items([(1, 'Matemáticas'), (2, 'Física'), (3, 'Química')])
# dict_values(['Matemáticas', 'Física', 'Química'])
# dict_values(['Álgebra', 'Física', 'Química'])
# {1: 'Álgebra', 3: 'Química'}

# %% [markdown]
# Algunos ejercicios:

# %%
#tuplas
respuestas = ("Yes", "No", "Yes", "Yes")

cantidad_yes = respuestas.count("Yes")

posicion_yes = respuestas.index("Yes")

resultado = (cantidad_yes, posicion_yes)

print("Cantidad de 'Yes':", cantidad_yes)
print("Primera posición de 'Yes':", posicion_yes)
print("Resultado final:", resultado)
# Out:
# Cantidad de 'Yes': 3
# Primera posición de 'Yes': 0
# Resultado final: (3, 0)

# %%
#listas
personajes = ["Sebas", "Joseph", "Camilo", "Jose"]

personajes.remove("Camilo")
personajes.append("Carlos")

resultado = personajes[1:3]

print(resultado)
# Out:
# ['Joseph', 'Jose']

# %%
#tuplas
grupo_A = set(["Ana", "Luis", "Carlos"])
grupo_B = set(["Luis", "María", "Carlos", "Sofía"])

resultado = grupo_A.intersection(grupo_B)

print(resultado)
# Out:
# {'Luis', 'Carlos'}

# %%
#diccionarios
estudiantes = {1: "Ana", 2: "Luis", 3: "Carlos"}

cursos = {
    "Ana": "Matemáticas",
    "Luis": "Física",
    "Carlos": "Química"
}

resultado = cursos[estudiantes[2]]

print(resultado)
# Out:
# Física

# %% [markdown]
# #Video sobre estructuras de Control de Flujo

# %%
#conversión de distintos tipos a False

print(0, "=>", bool(0))
print(0.0, "=>", bool(0.0))
print("", "=>", bool(""))
print([], "=>", bool([]))
print((), "=>", bool(()))
print(set(), "=>", bool(set()))
print({}, "=>", bool({}))
print(None, "=>", bool(None))
# Out:
# 0 => False
# 0.0 => False
#  => False
# [] => False
# () => False
# set() => False
# {} => False
# None => False

# %%
# Ejemplo de valores que se evalúan como True

print(100, "=>", bool(100))
print(2.718, "=>", bool(2.718))
print("Texto", "=>", bool("Texto"))
print([1, 2, 3], "=>", bool([1, 2, 3]))
print((4, 5), "=>", bool((4, 5)))
print({6, 7}, "=>", bool({6, 7}))
print({"a": 1}, "=>", bool({"a": 1}))
# Out:
# 100 => True
# 2.718 => True
# Texto => True
# [1, 2, 3] => True
# (4, 5) => True
# {6, 7} => True
# {'a': 1} => True

# %%
# Ejemplo if-else
nota = float(input("Ingrese su calificación: "))

if nota < 6:
    print("Estás reprobado, debes mejorar")
else:
    print("Estás aprobado, buen trabajo")
# Out:
# Ingrese su calificación: 9
# Estás aprobado, buen trabajo

# %%
#Ejemplo if-elif-else

nota = float(input("Ingrese su calificación: "))

if 0 <= nota < 6:
    print("Reprobado")
elif 6 <= nota < 8:
    print("Aprobado")
elif 8 <= nota < 9.5:
    print("Buen desempeño")
elif 9.5 <= nota <= 10:
    print("Excelente")
else:
    print("Calificación inválida")
# Out:
# Ingrese su calificación: 2
# Reprobado

# %%
# Ejemplo while
contador = 5
while contador > 0:
    print("Valor actual:", contador)
    contador -= 1
# Out:
# Valor actual: 5
# Valor actual: 4
# Valor actual: 3
# Valor actual: 2
# Valor actual: 1

# %%
# Ejemplo básico del for
for numero in [2, 4, 6, 8]:
    print("Elemento:", numero)
# Out:
# Elemento: 2
# Elemento: 4
# Elemento: 6
# Elemento: 8

# %%
# for sobre estructuras de datos

lista = [3, 2, 1]
tupla = (3, 2, 1)
conjunto = {3, 2, 1}
diccionario = {3: "Tres", 2: "Dos", 1: "Uno"}

for elemento in lista:
    print("Lista:", elemento)

for elemento in tupla:
    print("Tupla:", elemento)

for elemento in conjunto:
    print("Conjunto:", elemento)

for clave, valor in diccionario.items():
    print("Diccionario:", clave, "->", valor)
# Out:
# Lista: 3
# Lista: 2
# Lista: 1
# Tupla: 3
# Tupla: 2
# Tupla: 1
# Conjunto: 1
# Conjunto: 2
# Conjunto: 3
# Diccionario: 3 -> Tres
# Diccionario: 2 -> Dos
# Diccionario: 1 -> Uno

# %%
# Acceso por índices a una lista con un for

lista = ["Este", "es", "un", "ejemplo", "de", "lista"]

for i in range(len(lista)):
    print("Posición:", i, "- Valor:", lista[i])
# Out:
# Posición: 0 - Valor: Este
# Posición: 1 - Valor: es
# Posición: 2 - Valor: un
# Posición: 3 - Valor: ejemplo
# Posición: 4 - Valor: de
# Posición: 5 - Valor: lista

# %%
# for para visualizar el efecto de break y continue

for numero in range(6):
    if numero == 2:
        continue
    if numero == 5:
        break
    print("Número:", numero)
# Out:
# Número: 0
# Número: 1
# Número: 3
# Número: 4

# %%
# Visualización del efecto de la sentencia break

for numero in range(6):
    if numero == 4:
        break
    print("Valor:", numero)
# Out:
# Valor: 0
# Valor: 1
# Valor: 2
# Valor: 3

# %%
# Visualización del efecto de la sentencia continue

for numero in range(6):
    if numero == 2:
        continue
    print("Número:", numero)
# Out:
# Número: 0
# Número: 1
# Número: 3
# Número: 4
# Número: 5

# %%
# Uso del else en un while

intentos = 3
while intentos > 0:
    if input(">>> Ingrese la contraseña: ") == "Bobesponja14":
        print("¡Acceso concedido!")
        break
    intentos -= 1
    print("Contraseña incorrecta")
else:
    print("Se agotaron los intentos")
# Out:
# >>> Ingrese la contraseña: bobi
# Contraseña incorrecta
# >>> Ingrese la contraseña: esponjita
# Contraseña incorrecta
# >>> Ingrese la contraseña: Bobesponja14
# ¡Acceso concedido!
